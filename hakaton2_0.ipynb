# %% [markdown]
# <a href="https://colab.research.google.com/github/iKatePy/KION/blob/main/hakaton2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Код выполняет полную pipeline-автоматизацию:
#
#     загрузка видео,
#
#     выделение аудио,
#
#     анализ аудио и видео для определения сцен,
#
#     интеллектуальное объединение сцен на основе аудио и видео весов,
#
#     трекинг объектов в видео,
#
#     распознавание речи и получение субтитров,
#
#     финальная сегментация сцен с богатыми метаданными (объекты, текст),
#
#     визуализация сценообразования,
#
#     сохранение сцен отдельными видеофайлами,
#
#     создание подробного отчёта по сценам.

# %%
# !pip install -q torch torchvision torchaudio
# !pip install -q opencv-python pytube moviepy pydub scenedetect[opencv] transformers
# !pip install -q ultralytics
# !pip install -q git+https://github.com/facebookresearch/detectron2.git
# !pip install -q librosa pandas matplotlib seaborn
# !pip install -q speechrecognition
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.5 MB/s eta 0:00:00
#   Building wheel for detectron2 (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 24.4 MB/s eta 0:00:00

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from collections import defaultdict
from datetime import timedelta

# Видео обработка
from pytube import YouTube
from moviepy.editor import VideoFileClip
import scenedetect
from scenedetect.detectors import ContentDetector
from scenedetect.scene_manager import SceneManager

# Аудио обработка
import librosa
import librosa.display
from pydub import AudioSegment
import speech_recognition as sr

# Обработка субтитров
from transformers import pipeline

# Детекция и трекинг объектов
from ultralytics import YOLO
import torch
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
def download_youtube_video(url, output_path='./video.mp4'):
    yt = YouTube(url)
    stream = yt.streams.filter(file_extension='mp4', progressive=True).order_by('resolution').desc().first()
    stream.download(output_path=os.path.dirname(output_path), filename=os.path.basename(output_path))
    return output_path

# Пример использования (раскомментируйте для загрузки своего видео)
# video_path = download_youtube_video('https://www.youtube.com/watch?v=...')
# Или используйте свое видео
video_path = '30 секунд (2023)_1080p.mp4'

# %% [markdown]
# Функция для извлечения аудио из видео

# %%
def extract_audio(video_path, audio_path='audio.wav'):
    video = VideoFileClip(video_path)
    audio = video.audio
    audio.write_audiofile(audio_path, codec='pcm_s16le')
    return audio_path

audio_path = extract_audio(video_path)
# Out:
# MoviePy - Writing audio in audio.wav
# MoviePy - Done.

# %% [markdown]
# Анализ аудио для обнаружения сцен

# %% [markdown]
# Вычисляет аудиохарактеристики по окнам:
#
#     Нормализованная энергия RMS (Root Mean Square).
#
#     Нормализованный спектральный центроид (характеристика частотного распределения).
#
#     Zero Crossing Rate — количество пересечений аудиоволны с нулём (важно для различения тонов и шума).

# %%
def analyze_audio(audio_path, frame_length=2048, hop_length=512):
    # Загрузка аудио
    y, sr = librosa.load(audio_path)

    # Вычисление RMS энергии
    rms = librosa.feature.rms(y=y, frame_length=frame_length, hop_length=hop_length)[0]

    # Нормализация
    rms_normalized = (rms - np.min(rms)) / (np.max(rms) - np.min(rms))

    # Вычисление спектрального центроида
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr, n_fft=frame_length, hop_length=hop_length)[0]
    spectral_centroid_normalized = (spectral_centroid - np.min(spectral_centroid)) / (np.max(spectral_centroid) - np.min(spectral_centroid))

    # Вычисление zero crossing rate
    zcr = librosa.feature.zero_crossing_rate(y, frame_length=frame_length, hop_length=hop_length)[0]

    # Временная ось в секундах
    times = librosa.times_like(rms, sr=sr, hop_length=hop_length, n_fft=frame_length)

    return {
        'times': times,
        'rms': rms_normalized,
        'spectral_centroid': spectral_centroid_normalized,
        'zcr': zcr
    }

audio_features = analyze_audio(audio_path)

# Визуализация аудио признаков
def plot_audio_features(audio_features):
    plt.figure(figsize=(15, 10))

    plt.subplot(3, 1, 1)
    plt.plot(audio_features['times'], audio_features['rms'], label='RMS Energy')
    plt.title('Normalized RMS Energy')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    plt.subplot(3, 1, 2)
    plt.plot(audio_features['times'], audio_features['spectral_centroid'], label='Spectral Centroid', color='orange')
    plt.title('Normalized Spectral Centroid')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency')

    plt.subplot(3, 1, 3)
    plt.plot(audio_features['times'], audio_features['zcr'], label='Zero Crossing Rate', color='green')
    plt.title('Zero Crossing Rate')
    plt.xlabel('Time (s)')
    plt.ylabel('Rate')

    plt.tight_layout()
    plt.show()

plot_audio_features(audio_features)

# %% [markdown]
# Обнаружение сцен на основе видео контента

# %%
def detect_video_scenes(video_path, threshold=30.0):
    # Создаем менеджер сцен и детектор
    video = scenedetect.VideoManager([video_path])
    scene_manager = SceneManager()
    scene_manager.add_detector(ContentDetector(threshold=threshold))

    # Обрабатываем видео
    video.set_downscale_factor()
    video.start()
    scene_manager.detect_scenes(frame_source=video)

    # Получаем список сцен
    scene_list = scene_manager.get_scene_list()

    # Конвертируем в секунды
    scenes = []
    for scene in scene_list:
        start_time = scene[0].get_seconds()
        end_time = scene[1].get_seconds()
        scenes.append((start_time, end_time))

    return scenes

video_scenes = detect_video_scenes(video_path)
print(f"Обнаружено {len(video_scenes)} сцен на основе видео контента:")
for i, (start, end) in enumerate(video_scenes):
    print(f"Сцена {i+1}: {start:.2f} - {end:.2f} сек")
# Out:
# ERROR:pyscenedetect:VideoManager is deprecated and will be removed.
# INFO:pyscenedetect:Loaded 1 video, framerate: 24.000 FPS, resolution: 1920 x 1080
# INFO:pyscenedetect:Detecting scenes...
# Обнаружено 196 сцен на основе видео контента:
# Сцена 1: 0.00 - 12.62 сек
# Сцена 2: 12.62 - 16.75 сек
# Сцена 3: 16.75 - 20.79 сек
# Сцена 4: 20.79 - 26.92 сек
# Сцена 5: 26.92 - 31.08 сек
# Сцена 6: 31.08 - 40.12 сек
# Сцена 7: 40.12 - 43.67 сек
# Сцена 8: 43.67 - 50.33 сек
# Сцена 9: 50.33 - 52.29 сек
# Сцена 10: 52.29 - 55.71 сек
# Сцена 11: 55.71 - 59.21 сек
# Сцена 12: 59.21 - 60.38 сек
# Сцена 13: 60.38 - 63.29 сек
# Сцена 14: 63.29 - 64.62 сек
# Сцена 15: 64.62 - 72.00 сек
# Сцена 16: 72.00 - 73.21 сек
# Сцена 17: 73.21 - 76.54 сек
# Сцена 18: 76.54 - 79.25 сек
# Сцена 19: 79.25 - 81.88 сек
# Сцена 20: 81.88 - 83.54 сек
# Сцена 21: 83.54 - 85.42 сек
# Сцена 22: 85.42 - 87.17 сек
# Сцена 23: 87.17 - 91.29 сек
# Сцена 24: 91.29 - 103.38 сек
# Сцена 25: 103.38 - 111.79 сек
# Сцена 26: 111.79 - 117.88 сек
# Сцена 27: 117.88 - 121.00 сек
# Сцена 28: 121.00 - 133.92 сек
# Сцена 29: 133.92 - 139.75 сек
# Сцена 30: 139.75 - 146.33 сек
# Сцена 31: 146.33 - 168.83 сек
# Сцена 32: 168.83 - 176.71 сек
# Сцена 33: 176.71 - 180.12 сек
# Сцена 34: 180.12 - 193.38 сек
# Сцена 35: 193.38 - 204.71 сек
# Сцена 36: 204.71 - 209.71 сек
# Сцена 37: 209.71 - 212.83 сек
# Сцена 38: 212.83 - 216.54 сек
# Сцена 39: 216.54 - 222.12 сек
# Сцена 40: 222.12 - 228.96 сек
# Сцена 41: 228.96 - 234.12 сек
# Сцена 42: 234.12 - 236.83 сек
# Сцена 43: 236.83 - 241.42 сек
# Сцена 44: 241.42 - 244.29 сек
# Сцена 45: 244.29 - 248.79 сек
# Сцена 46: 248.79 - 268.88 сек
# Сцена 47: 268.88 - 273.38 сек
# Сцена 48: 273.38 - 291.96 сек
# Сцена 49: 291.96 - 303.29 сек
# Сцена 50: 303.29 - 310.21 сек
# Сцена 51: 310.21 - 313.00 сек
# Сцена 52: 313.00 - 318.62 сек
# Сцена 53: 318.62 - 321.58 сек
# Сцена 54: 321.58 - 326.04 сек
# Сцена 55: 326.04 - 333.83 сек
# Сцена 56: 333.83 - 336.29 сек
# Сцена 57: 336.29 - 341.54 сек
# Сцена 58: 341.54 - 345.04 сек
# Сцена 59: 345.04 - 346.71 сек
# Сцена 60: 346.71 - 351.38 сек
# Сцена 61: 351.38 - 359.92 сек
# Сцена 62: 359.92 - 363.38 сек
# Сцена 63: 363.38 - 374.38 сек
# Сцена 64: 374.38 - 382.08 сек
# Сцена 65: 382.08 - 390.17 сек
# Сцена 66: 390.17 - 396.75 сек
# Сцена 67: 396.75 - 405.92 сек
# Сцена 68: 405.92 - 415.71 сек
# Сцена 69: 415.71 - 419.71 сек
# Сцена 70: 419.71 - 428.83 сек
# Сцена 71: 428.83 - 432.42 сек
# Сцена 72: 432.42 - 446.25 сек
# Сцена 73: 446.25 - 454.46 сек
# Сцена 74: 454.46 - 460.62 сек
# Сцена 75: 460.62 - 473.50 сек
# Сцена 76: 473.50 - 483.88 сек
# Сцена 77: 483.88 - 486.17 сек
# Сцена 78: 486.17 - 511.12 сек
# Сцена 79: 511.12 - 518.62 сек
# Сцена 80: 518.62 - 524.92 сек
# Сцена 81: 524.92 - 536.67 сек
# Сцена 82: 536.67 - 542.17 сек
# Сцена 83: 542.17 - 545.67 сек
# Сцена 84: 545.67 - 548.79 сек
# Сцена 85: 548.79 - 554.42 сек
# Сцена 86: 554.42 - 557.67 сек
# Сцена 87: 557.67 - 562.29 сек
# Сцена 88: 562.29 - 567.25 сек
# Сцена 89: 567.25 - 572.79 сек
# Сцена 90: 572.79 - 581.08 сек
# Сцена 91: 581.08 - 588.96 сек
# Сцена 92: 588.96 - 594.42 сек
# Сцена 93: 594.42 - 599.88 сек
# Сцена 94: 599.88 - 607.67 сек
# Сцена 95: 607.67 - 610.33 сек
# Сцена 96: 610.33 - 616.12 сек
# Сцена 97: 616.12 - 622.08 сек
# Сцена 98: 622.08 - 630.00 сек
# Сцена 99: 630.00 - 643.33 сек
# Сцена 100: 643.33 - 648.12 сек
# Сцена 101: 648.12 - 653.50 сек
# Сцена 102: 653.50 - 659.12 сек
# Сцена 103: 659.12 - 668.75 сек
# Сцена 104: 668.75 - 682.46 сек
# Сцена 105: 682.46 - 689.42 сек
# Сцена 106: 689.42 - 691.54 сек
# Сцена 107: 691.54 - 693.71 сек
# Сцена 108: 693.71 - 695.46 сек
# Сцена 109: 695.46 - 699.38 сек
# Сцена 110: 699.38 - 707.96 сек
# Сцена 111: 707.96 - 715.33 сек
# Сцена 112: 715.33 - 719.04 сек
# Сцена 113: 719.04 - 724.71 сек
# Сцена 114: 724.71 - 731.67 сек
# Сцена 115: 731.67 - 734.04 сек
# Сцена 116: 734.04 - 738.21 сек
# Сцена 117: 738.21 - 742.00 сек
# Сцена 118: 742.00 - 751.71 сек
# Сцена 119: 751.71 - 754.38 сек
# Сцена 120: 754.38 - 757.71 сек
# Сцена 121: 757.71 - 760.79 сек
# Сцена 122: 760.79 - 769.38 сек
# Сцена 123: 769.38 - 773.92 сек
# Сцена 124: 773.92 - 780.04 сек
# Сцена 125: 780.04 - 786.38 сек
# Сцена 126: 786.38 - 788.88 сек
# Сцена 127: 788.88 - 793.96 сек
# Сцена 128: 793.96 - 796.21 сек
# Сцена 129: 796.21 - 798.00 сек
# Сцена 130: 798.00 - 800.33 сек
# Сцена 131: 800.33 - 803.62 сек
# Сцена 132: 803.62 - 811.92 сек
# Сцена 133: 811.92 - 819.08 сек
# Сцена 134: 819.08 - 826.62 сек
# Сцена 135: 826.62 - 830.29 сек
# Сцена 136: 830.29 - 834.92 сек
# Сцена 137: 834.92 - 840.25 сек
# Сцена 138: 840.25 - 844.54 сек
# Сцена 139: 844.54 - 849.58 сек
# Сцена 140: 849.58 - 865.58 сек
# Сцена 141: 865.58 - 868.83 сек
# Сцена 142: 868.83 - 874.08 сек
# Сцена 143: 874.08 - 882.12 сек
# Сцена 144: 882.12 - 886.62 сек
# Сцена 145: 886.62 - 892.92 сек
# Сцена 146: 892.92 - 899.62 сек
# Сцена 147: 899.62 - 910.21 сек
# Сцена 148: 910.21 - 914.79 сек
# Сцена 149: 914.79 - 919.38 сек
# Сцена 150: 919.38 - 923.46 сек
# Сцена 151: 923.46 - 927.50 сек
# Сцена 152: 927.50 - 930.58 сек
# Сцена 153: 930.58 - 938.08 сек
# Сцена 154: 938.08 - 960.92 сек
# Сцена 155: 960.92 - 967.88 сек
# Сцена 156: 967.88 - 974.08 сек
# Сцена 157: 974.08 - 976.62 сек
# Сцена 158: 976.62 - 980.25 сек
# Сцена 159: 980.25 - 985.58 сек
# Сцена 160: 985.58 - 987.46 сек
# Сцена 161: 987.46 - 989.46 сек
# Сцена 162: 989.46 - 992.46 сек
# Сцена 163: 992.46 - 994.17 сек
# Сцена 164: 994.17 - 995.33 сек
# Сцена 165: 995.33 - 999.54 сек
# Сцена 166: 999.54 - 1002.62 сек
# Сцена 167: 1002.62 - 1004.12 сек
# Сцена 168: 1004.12 - 1009.50 сек
# Сцена 169: 1009.50 - 1012.62 сек
# Сцена 170: 1012.62 - 1018.71 сек
# Сцена 171: 1018.71 - 1023.00 сек
# Сцена 172: 1023.00 - 1025.88 сек
# Сцена 173: 1025.88 - 1029.42 сек
# Сцена 174: 1029.42 - 1031.42 сек
# Сцена 175: 1031.42 - 1045.21 сек
# Сцена 176: 1045.21 - 1048.88 сек
# Сцена 177: 1048.88 - 1053.00 сек
# Сцена 178: 1053.00 - 1054.62 сек
# Сцена 179: 1054.62 - 1060.08 сек
# Сцена 180: 1060.08 - 1065.54 сек
# Сцена 181: 1065.54 - 1069.04 сек
# Сцена 182: 1069.04 - 1072.12 сек
# Сцена 183: 1072.12 - 1081.88 сек
# Сцена 184: 1081.88 - 1086.12 сек
# Сцена 185: 1086.12 - 1088.67 сек
# Сцена 186: 1088.67 - 1092.38 сек
# Сцена 187: 1092.38 - 1098.79 сек
# Сцена 188: 1098.79 - 1103.08 сек
# Сцена 189: 1103.08 - 1108.75 сек
# Сцена 190: 1108.75 - 1112.38 сек
# Сцена 191: 1112.38 - 1114.67 сек
# Сцена 192: 1114.67 - 1121.12 сек
# Сцена 193: 1121.12 - 1124.08 сек
# Сцена 194: 1124.08 - 1127.50 сек
# Сцена 195: 1127.50 - 1136.17 сек
# Сцена 196: 1136.17 - 1160.38 сек

# %% [markdown]
# Обнаружение сцен на основе аудио

# %%
def detect_audio_scenes(audio_features, rms_threshold=0.3, centroid_threshold=0.4, min_scene_duration=3.0):
    times = audio_features['times']
    rms = audio_features['rms']
    spectral_centroid = audio_features['spectral_centroid']

    scenes = []
    current_scene_start = 0.0

    for i in range(1, len(times)):
        # Проверяем изменения в RMS и спектральном центроиде
        rms_change = abs(rms[i] - rms[i-1])
        centroid_change = abs(spectral_centroid[i] - spectral_centroid[i-1])

        # Если изменения значительные, считаем это границей сцены
        if rms_change > rms_threshold or centroid_change > centroid_threshold:
            scene_duration = times[i] - current_scene_start
            if scene_duration >= min_scene_duration:
                scenes.append((current_scene_start, times[i]))
                current_scene_start = times[i]

    # Добавляем последнюю сцену
    if current_scene_start < times[-1]:
        scenes.append((current_scene_start, times[-1]))

    return scenes

audio_scenes = detect_audio_scenes(audio_features)
print(f"\nОбнаружено {len(audio_scenes)} сцен на основе аудио анализа:")
for i, (start, end) in enumerate(audio_scenes):
    print(f"Сцена {i+1}: {start:.2f} - {end:.2f} сек")
# Out:
# Обнаружено 7 сцен на основе аудио анализа:
# Сцена 1: 0.00 - 95.11 сек
# Сцена 2: 95.11 - 494.72 сек
# Сцена 3: 494.72 - 1126.70 сек
# Сцена 4: 1126.70 - 1151.45 сек
# Сцена 5: 1151.45 - 1155.01 сек
# Сцена 6: 1155.01 - 1158.33 сек
# Сцена 7: 1158.33 - 1160.42 сек

# %% [markdown]
# Объединение видео и аудио сцен

# %% [markdown]
# Для диалоговых сцен:
#
#
# merge_scenes(video_scenes, audio_scenes,
#             video_weight=0.4,  # меньше вес видео (частые смены кадров)
#             audio_weight=0.6,  # больше вес аудио (диалог продолжается)
#             max_scene_duration=90.0)
# Для экшен-сцен:
#
#
# merge_scenes(video_scenes, audio_scenes,
#             video_weight=0.8,  # больше вес видео (важны визуальные изменения)
#             audio_weight=0.2,
#             max_scene_duration=30.0)
# Балансный вариант:
#
#
# merge_scenes(video_scenes, audio_scenes,
#             video_weight=0.6,
#             audio_weight=0.4,
#             max_scene_duration=60.0)
#
#
# Объединяет сцены с учётом весов, длительности, перекрытий и максимальной длительности.

# %%
def merge_scenes(video_scenes, audio_scenes,
                video_weight=0.7, audio_weight=0.3,
                min_scene_duration=3.0, max_scene_duration=120.0,
                overlap_threshold=2.0):
    """
    Улучшенный алгоритм объединения сцен с учетом:
    - весовых коэффициентов для видео и аудио
    - минимальной и максимальной длительности сцен
    - сохранения логических границ
    """
    # Нормализуем и взвешиваем сцены
    weighted_scenes = []

    # Добавляем видео сцены с весом
    for start, end in video_scenes:
        duration = end - start
        if duration >= min_scene_duration:
            weighted_scenes.append({
                'start': start,
                'end': end,
                'weight': video_weight,
                'type': 'video'
            })

    # Добавляем аудио сцены с весом
    for start, end in audio_scenes:
        duration = end - start
        if duration >= min_scene_duration:
            weighted_scenes.append({
                'start': start,
                'end': end,
                'weight': audio_weight,
                'type': 'audio'
            })

    # Сортируем все сцены по времени начала
    weighted_scenes.sort(key=lambda x: x['start'])

    if not weighted_scenes:
        return []

    # Алгоритм интеллектуального объединения
    merged_scenes = []
    current_scene = weighted_scenes[0].copy()

    for scene in weighted_scenes[1:]:
        # Проверяем перекрытие или близость сцен
        scene_overlap = (scene['start'] <= current_scene['end'] + overlap_threshold)

        # Проверяем максимальную длительность
        duration_exceeded = (scene['end'] - current_scene['start']) > max_scene_duration

        # Если сцены пересекаются и не превышают максимальную длительность
        if scene_overlap and not duration_exceeded:
            # Объединяем сцены с учетом весов
            if scene['type'] == 'video' and current_scene['type'] != 'video':
                current_scene['end'] = scene['end']
                current_scene['weight'] += scene['weight']
                current_scene['type'] = 'mixed'
            elif scene['weight'] > current_scene['weight']:
                current_scene['end'] = scene['end']
                current_scene['weight'] += scene['weight']
                if scene['type'] != current_scene['type']:
                    current_scene['type'] = 'mixed'
            else:
                current_scene['end'] = max(current_scene['end'], scene['end'])
                current_scene['weight'] += scene['weight'] * 0.5  # меньший вес для расширения
        else:
            # Сохраняем текущую сцену и начинаем новую
            if current_scene['end'] - current_scene['start'] >= min_scene_duration:
                merged_scenes.append((current_scene['start'], current_scene['end']))
            current_scene = scene.copy()

    # Добавляем последнюю сцену
    if current_scene['end'] - current_scene['start'] >= min_scene_duration:
        merged_scenes.append((current_scene['start'], current_scene['end']))

    # Фильтруем слишком короткие сцены, которые могли появиться после объединения
    merged_scenes = [(start, end) for start, end in merged_scenes
                    if end - start >= min_scene_duration]

    return merged_scenes

# Параметры для нашего случая
video_weight = 0.7  # больший вес для видео сцен
audio_weight = 0.3  # меньший вес для аудио сцен
min_duration = 3.0  # минимальная длительность сцены в секундах
max_duration = 60.0 # максимальная длительность сцены в секундах

# Объединяем сцены с новыми параметрами
merged_scenes = merge_scenes(video_scenes, audio_scenes,
                           video_weight=video_weight,
                           audio_weight=audio_weight,
                           min_scene_duration=min_duration,
                           max_scene_duration=max_duration)

print(f"Обнаружено {len(merged_scenes)} сцен после улучшенного объединения:")
for i, (start, end) in enumerate(merged_scenes):
    print(f"Сцена {i+1}: {start:.2f} - {end:.2f} сек (длительность: {end-start:.2f} сек)")

# Финализируем сцены с трекингом объектов
final_scenes = final_scene_segmentation(merged_scenes, tracks_info)

# Визуализируем результат
visualize_scenes(final_scenes, video_path)
# Out:
# Обнаружено 36 сцен после улучшенного объединения:
# Сцена 1: 0.00 - 12.62 сек (длительность: 12.62 сек)
# Сцена 2: 0.00 - 59.21 сек (длительность: 59.21 сек)
# Сцена 3: 64.62 - 76.54 сек (длительность: 11.92 сек)
# Сцена 4: 87.17 - 103.38 сек (длительность: 16.21 сек)
# Сцена 5: 95.11 - 146.33 сек (длительность: 51.22 сек)
# Сцена 6: 146.33 - 204.71 сек (длительность: 58.38 сек)
# Сцена 7: 204.71 - 234.12 сек (длительность: 29.42 сек)
# Сцена 8: 236.83 - 241.42 сек (длительность: 4.58 сек)
# Сцена 9: 244.29 - 303.29 сек (длительность: 59.00 сек)
# Сцена 10: 303.29 - 310.21 сек (длительность: 6.92 сек)
# Сцена 11: 313.00 - 318.62 сек (длительность: 5.62 сек)
# Сцена 12: 321.58 - 333.83 сек (длительность: 12.25 сек)
# Сцена 13: 336.29 - 390.17 сек (длительность: 53.88 сек)
# Сцена 14: 390.17 - 446.25 сек (длительность: 56.08 сек)
# Сцена 15: 446.25 - 483.88 сек (длительность: 37.62 сек)
# Сцена 16: 486.17 - 511.12 сек (длительность: 24.96 сек)
# Сцена 17: 494.72 - 554.42 сек (длительность: 59.69 сек)
# Сцена 18: 554.42 - 607.67 сек (длительность: 53.25 сек)
# Сцена 19: 610.33 - 668.75 сек (длительность: 58.42 сек)
# Сцена 20: 668.75 - 689.42 сек (длительность: 20.67 сек)
# Сцена 21: 695.46 - 731.67 сек (длительность: 36.21 сек)
# Сцена 22: 734.04 - 751.71 сек (длительность: 17.67 сек)
# Сцена 23: 754.38 - 786.38 сек (длительность: 32.00 сек)
# Сцена 24: 788.88 - 793.96 сек (длительность: 5.08 сек)
# Сцена 25: 800.33 - 849.58 сек (длительность: 49.25 сек)
# Сцена 26: 849.58 - 899.62 сек (длительность: 50.04 сек)
# Сцена 27: 899.62 - 938.08 сек (длительность: 38.46 сек)
# Сцена 28: 938.08 - 974.08 сек (длительность: 36.00 сек)
# Сцена 29: 976.62 - 985.58 сек (длительность: 8.96 сек)
# Сцена 30: 989.46 - 992.46 сек (длительность: 3.00 сек)
# Сцена 31: 995.33 - 1023.00 сек (длительность: 27.67 сек)
# Сцена 32: 1025.88 - 1081.88 сек (длительность: 56.00 сек)
# Сцена 33: 1081.88 - 1086.12 сек (длительность: 4.25 сек)
# Сцена 34: 1088.67 - 1112.38 сек (длительность: 23.71 сек)
# Сцена 35: 1114.67 - 1121.12 сек (длительность: 6.46 сек)
# Сцена 36: 1124.08 - 1160.38 сек (длительность: 36.29 сек)

# %% [markdown]
# Динамическое определение весов (не опробовано):

# %%
def calculate_dynamic_weights(video_scenes, audio_scenes):
    # Анализируем распределение длительностей
    avg_video_duration = np.mean([end-start for start,end in video_scenes])
    avg_audio_duration = np.mean([end-start for start,end in audio_scenes])

    # Чем больше средняя длительность, тем меньше вес
    video_weight = min(0.8, 0.2 + 0.6*(1 - avg_video_duration/120))
    audio_weight = min(0.8, 0.2 + 0.6*(1 - avg_audio_duration/300))

    return video_weight, audio_weight

v_weight, a_weight = calculate_dynamic_weights(video_scenes, audio_scenes)

# %% [markdown]
# Постобработка для объединения слишком коротких сцен:

# %%
def postprocess_scenes(scenes, min_duration=5.0):
    if not scenes:
        return []

    processed = []
    current_start, current_end = scenes[0]

    for start, end in scenes[1:]:
        if start - current_end < min_duration*2:  # близкие сцены
            current_end = end
        else:
            if current_end - current_start >= min_duration:
                processed.append((current_start, current_end))
            current_start, current_end = start, end

    if current_end - current_start >= min_duration:
        processed.append((current_start, current_end))

    return processed

# %% [markdown]
# Трекинг объектов с помощью YOLOv8 и DeepSORT

# %%
# Загрузка модели YOLOv8
model = YOLO('yolov8l.pt')  # Используем большую модель для лучшей точности

# Функция для трекинга объектов в видео
def track_objects(video_path, output_path='output_tracked.mp4'):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Создаем VideoWriter для сохранения результата
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Словарь для хранения информации о треках
    tracks_info = defaultdict(list)

    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Выполняем трекинг с YOLOv8
        results = model.track(frame, persist=True, tracker="bytetrack.yaml")

        # Визуализация результатов
        annotated_frame = results[0].plot()

        # Сохраняем информацию о треках
        if results[0].boxes.id is not None:
            for box, track_id in zip(results[0].boxes, results[0].boxes.id):
                x1, y1, x2, y2 = box.xyxy[0].tolist()
                conf = box.conf[0].item()
                cls = box.cls[0].item()

                tracks_info[int(track_id)].append({
                    'frame': frame_count,
                    'time': frame_count / fps,
                    'bbox': [x1, y1, x2, y2],
                    'confidence': conf,
                    'class': cls
                })

        # Записываем кадр
        out.write(annotated_frame)
        frame_count += 1

    cap.release()
    out.release()

    return tracks_info, output_path

# Запускаем трекинг (может занять много времени)
tracks_info, tracked_video_path = track_objects(video_path)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt'...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 151MB/s]
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 (no detections), 1322.7ms
# Speed: 2.6ms preprocess, 1322.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1304.1ms
# Speed: 2.7ms preprocess, 1304.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1609.5ms
# Speed: 4.5ms preprocess, 1609.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1268.7ms
# Speed: 2.8ms preprocess, 1268.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1264.9ms
# Speed: 2.3ms preprocess, 1264.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1345.8ms
# Speed: 3.2ms preprocess, 1345.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1315.2ms
# Speed: 3.1ms preprocess, 1315.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1282.2ms
# Speed: 2.8ms preprocess, 1282.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1294.3ms
# Speed: 2.5ms preprocess, 1294.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1357.6ms
# Speed: 2.8ms preprocess, 1357.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1527.7ms
# Speed: 2.7ms preprocess, 1527.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1296.7ms
# Speed: 4.7ms preprocess, 1296.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1270.1ms
# Speed: 2.1ms preprocess, 1270.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1315.6ms
# Speed: 2.7ms preprocess, 1315.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1336.6ms
# Speed: 3.0ms preprocess, 1336.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1292.1ms
# Speed: 3.3ms preprocess, 1292.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1333.5ms
# Speed: 2.6ms preprocess, 1333.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1329.0ms
# Speed: 2.7ms preprocess, 1329.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1392.1ms
# Speed: 2.3ms preprocess, 1392.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1513.5ms
# Speed: 2.5ms preprocess, 1513.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1321.5ms
# Speed: 2.4ms preprocess, 1321.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1328.3ms
# Speed: 2.8ms preprocess, 1328.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1278.3ms
# Speed: 2.4ms preprocess, 1278.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1318.9ms
# Speed: 2.9ms preprocess, 1318.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1330.1ms
# Speed: 2.3ms preprocess, 1330.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1334.1ms
# Speed: 3.3ms preprocess, 1334.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1229.4ms
# Speed: 2.7ms preprocess, 1229.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1598.5ms
# Speed: 2.2ms preprocess, 1598.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1333.0ms
# Speed: 2.8ms preprocess, 1333.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1281.4ms
# Speed: 2.5ms preprocess, 1281.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1279.8ms
# Speed: 3.7ms preprocess, 1279.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1268.4ms
# Speed: 3.0ms preprocess, 1268.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1280.7ms
# Speed: 2.7ms preprocess, 1280.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1281.1ms
# Speed: 2.4ms preprocess, 1281.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1308.5ms
# Speed: 2.5ms preprocess, 1308.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 car, 2 bottles, 1 wine glass, 2 cups, 2 apples, 1 orange, 1 chair, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1574.7ms
# Speed: 2.7ms preprocess, 1574.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1358.1ms
# Speed: 3.5ms preprocess, 1358.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1290.3ms
# Speed: 2.3ms preprocess, 1290.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1277.8ms
# Speed: 2.5ms preprocess, 1277.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1293.5ms
# Speed: 5.5ms preprocess, 1293.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1317.9ms
# Speed: 2.3ms preprocess, 1317.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1337.0ms
# Speed: 4.7ms preprocess, 1337.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1298.3ms
# Speed: 2.7ms preprocess, 1298.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1473.8ms
# Speed: 3.1ms preprocess, 1473.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1419.2ms
# Speed: 3.2ms preprocess, 1419.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1308.1ms
# Speed: 2.3ms preprocess, 1308.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1 refrigerator, 1284.5ms
# Speed: 4.6ms preprocess, 1284.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1274.8ms
# Speed: 3.3ms preprocess, 1274.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1256.0ms
# Speed: 2.7ms preprocess, 1256.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1300.0ms
# Speed: 3.1ms preprocess, 1300.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1330.6ms
# Speed: 3.1ms preprocess, 1330.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1346.4ms
# Speed: 3.9ms preprocess, 1346.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1630.0ms
# Speed: 2.6ms preprocess, 1630.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1 refrigerator, 1336.0ms
# Speed: 2.5ms preprocess, 1336.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1347.0ms
# Speed: 3.5ms preprocess, 1347.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1314.7ms
# Speed: 5.0ms preprocess, 1314.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1279.2ms
# Speed: 2.4ms preprocess, 1279.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1309.5ms
# Speed: 2.6ms preprocess, 1309.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1303.5ms
# Speed: 2.9ms preprocess, 1303.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1314.5ms
# Speed: 3.8ms preprocess, 1314.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1633.5ms
# Speed: 2.8ms preprocess, 1633.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1338.0ms
# Speed: 3.5ms preprocess, 1338.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1294.3ms
# Speed: 3.3ms preprocess, 1294.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1318.6ms
# Speed: 2.7ms preprocess, 1318.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1270.9ms
# Speed: 2.3ms preprocess, 1270.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1282.4ms
# Speed: 3.3ms preprocess, 1282.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1272.9ms
# Speed: 2.3ms preprocess, 1272.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1286.9ms
# Speed: 3.1ms preprocess, 1286.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 microwave, 1 refrigerator, 1547.7ms
# Speed: 2.5ms preprocess, 1547.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1360.1ms
# Speed: 2.8ms preprocess, 1360.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1329.9ms
# Speed: 2.5ms preprocess, 1329.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1294.5ms
# Speed: 2.8ms preprocess, 1294.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1291.7ms
# Speed: 2.4ms preprocess, 1291.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1328.8ms
# Speed: 2.8ms preprocess, 1328.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1325.8ms
# Speed: 2.9ms preprocess, 1325.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1342.1ms
# Speed: 2.7ms preprocess, 1342.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1 refrigerator, 1457.5ms
# Speed: 3.1ms preprocess, 1457.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1492.2ms
# Speed: 3.0ms preprocess, 1492.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1260.5ms
# Speed: 2.2ms preprocess, 1260.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1318.5ms
# Speed: 2.6ms preprocess, 1318.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1316.3ms
# Speed: 3.2ms preprocess, 1316.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1333.3ms
# Speed: 2.7ms preprocess, 1333.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1328.6ms
# Speed: 3.6ms preprocess, 1328.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1348.5ms
# Speed: 3.0ms preprocess, 1348.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1408.2ms
# Speed: 2.8ms preprocess, 1408.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1569.2ms
# Speed: 3.2ms preprocess, 1569.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1271.3ms
# Speed: 2.6ms preprocess, 1271.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1272.5ms
# Speed: 2.4ms preprocess, 1272.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1325.0ms
# Speed: 2.4ms preprocess, 1325.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1328.7ms
# Speed: 2.4ms preprocess, 1328.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1313.8ms
# Speed: 7.5ms preprocess, 1313.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1287.6ms
# Speed: 2.8ms preprocess, 1287.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1313.5ms
# Speed: 3.0ms preprocess, 1313.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1608.9ms
# Speed: 2.5ms preprocess, 1608.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1349.1ms
# Speed: 2.8ms preprocess, 1349.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1315.3ms
# Speed: 2.8ms preprocess, 1315.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1354.5ms
# Speed: 2.9ms preprocess, 1354.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1324.4ms
# Speed: 4.0ms preprocess, 1324.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1310.3ms
# Speed: 2.6ms preprocess, 1310.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1275.7ms
# Speed: 2.4ms preprocess, 1275.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1293.0ms
# Speed: 2.4ms preprocess, 1293.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1646.9ms
# Speed: 2.8ms preprocess, 1646.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1319.9ms
# Speed: 4.0ms preprocess, 1319.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1268.8ms
# Speed: 2.5ms preprocess, 1268.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1248.1ms
# Speed: 2.4ms preprocess, 1248.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1281.3ms
# Speed: 2.4ms preprocess, 1281.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1338.6ms
# Speed: 2.8ms preprocess, 1338.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1337.9ms
# Speed: 5.2ms preprocess, 1337.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1302.8ms
# Speed: 2.6ms preprocess, 1302.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1529.7ms
# Speed: 3.0ms preprocess, 1529.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1 refrigerator, 1336.1ms
# Speed: 2.5ms preprocess, 1336.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1267.0ms
# Speed: 2.2ms preprocess, 1267.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1 refrigerator, 1302.7ms
# Speed: 2.5ms preprocess, 1302.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1291.8ms
# Speed: 2.7ms preprocess, 1291.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1312.2ms
# Speed: 3.7ms preprocess, 1312.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1257.6ms
# Speed: 2.4ms preprocess, 1257.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1314.3ms
# Speed: 6.9ms preprocess, 1314.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1485.1ms
# Speed: 2.7ms preprocess, 1485.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1518.6ms
# Speed: 3.4ms preprocess, 1518.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1285.2ms
# Speed: 6.2ms preprocess, 1285.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1305.4ms
# Speed: 2.4ms preprocess, 1305.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1306.9ms
# Speed: 2.9ms preprocess, 1306.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1319.7ms
# Speed: 2.4ms preprocess, 1319.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1266.9ms
# Speed: 2.6ms preprocess, 1266.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1261.5ms
# Speed: 2.5ms preprocess, 1261.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1300.1ms
# Speed: 2.3ms preprocess, 1300.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1625.0ms
# Speed: 2.7ms preprocess, 1625.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1318.4ms
# Speed: 3.7ms preprocess, 1318.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1331.8ms
# Speed: 3.7ms preprocess, 1331.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1310.8ms
# Speed: 7.8ms preprocess, 1310.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1287.9ms
# Speed: 2.5ms preprocess, 1287.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1305.1ms
# Speed: 2.8ms preprocess, 1305.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1351.4ms
# Speed: 2.3ms preprocess, 1351.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1286.7ms
# Speed: 3.4ms preprocess, 1286.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1612.0ms
# Speed: 2.8ms preprocess, 1612.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1294.0ms
# Speed: 2.8ms preprocess, 1294.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1272.4ms
# Speed: 2.4ms preprocess, 1272.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1281.3ms
# Speed: 2.4ms preprocess, 1281.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1280.9ms
# Speed: 2.6ms preprocess, 1280.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1280.2ms
# Speed: 2.5ms preprocess, 1280.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1283.9ms
# Speed: 2.5ms preprocess, 1283.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1286.8ms
# Speed: 2.3ms preprocess, 1286.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1429.8ms
# Speed: 9.3ms preprocess, 1429.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1454.0ms
# Speed: 7.9ms preprocess, 1454.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1307.6ms
# Speed: 2.5ms preprocess, 1307.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1263.2ms
# Speed: 2.4ms preprocess, 1263.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1337.4ms
# Speed: 3.6ms preprocess, 1337.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1311.0ms
# Speed: 2.6ms preprocess, 1311.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1283.9ms
# Speed: 2.8ms preprocess, 1283.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1332.6ms
# Speed: 4.1ms preprocess, 1332.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1325.3ms
# Speed: 2.6ms preprocess, 1325.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1601.0ms
# Speed: 2.7ms preprocess, 1601.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1355.6ms
# Speed: 2.8ms preprocess, 1355.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1332.1ms
# Speed: 2.8ms preprocess, 1332.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1272.3ms
# Speed: 2.4ms preprocess, 1272.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1291.8ms
# Speed: 2.4ms preprocess, 1291.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1340.1ms
# Speed: 2.7ms preprocess, 1340.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1331.3ms
# Speed: 3.4ms preprocess, 1331.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1261.3ms
# Speed: 2.2ms preprocess, 1261.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1627.1ms
# Speed: 2.4ms preprocess, 1627.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1289.2ms
# Speed: 2.5ms preprocess, 1289.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1299.6ms
# Speed: 3.0ms preprocess, 1299.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1335.5ms
# Speed: 2.5ms preprocess, 1335.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1251.1ms
# Speed: 2.4ms preprocess, 1251.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1272.0ms
# Speed: 5.8ms preprocess, 1272.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1277.1ms
# Speed: 2.3ms preprocess, 1277.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1286.3ms
# Speed: 2.5ms preprocess, 1286.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1570.8ms
# Speed: 2.9ms preprocess, 1570.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1490.1ms
# Speed: 2.9ms preprocess, 1490.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1382.1ms
# Speed: 3.2ms preprocess, 1382.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1276.9ms
# Speed: 3.8ms preprocess, 1276.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1292.0ms
# Speed: 2.3ms preprocess, 1292.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1 refrigerator, 1329.6ms
# Speed: 2.8ms preprocess, 1329.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1 refrigerator, 1348.7ms
# Speed: 2.4ms preprocess, 1348.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1299.1ms
# Speed: 2.6ms preprocess, 1299.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1471.7ms
# Speed: 3.1ms preprocess, 1471.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 1 microwave, 1501.6ms
# Speed: 7.5ms preprocess, 1501.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 2 microwaves, 1332.1ms
# Speed: 2.8ms preprocess, 1332.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1322.8ms
# Speed: 3.8ms preprocess, 1322.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1285.3ms
# Speed: 2.4ms preprocess, 1285.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1275.5ms
# Speed: 2.7ms preprocess, 1275.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1283.3ms
# Speed: 2.4ms preprocess, 1283.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1297.9ms
# Speed: 2.5ms preprocess, 1297.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1375.0ms
# Speed: 3.0ms preprocess, 1375.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1556.9ms
# Speed: 2.9ms preprocess, 1556.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1313.4ms
# Speed: 3.1ms preprocess, 1313.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1260.7ms
# Speed: 2.4ms preprocess, 1260.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1251.4ms
# Speed: 2.4ms preprocess, 1251.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bottle, 1 wine glass, 1 cup, 2 apples, 1 potted plant, 1 dining table, 1 tv, 2 microwaves, 1291.2ms
# Speed: 2.8ms preprocess, 1291.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1321.9ms
# Speed: 2.7ms preprocess, 1321.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1326.5ms
# Speed: 2.8ms preprocess, 1326.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1273.9ms
# Speed: 2.5ms preprocess, 1273.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1610.3ms
# Speed: 2.4ms preprocess, 1610.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1306.4ms
# Speed: 2.8ms preprocess, 1306.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1318.2ms
# Speed: 2.6ms preprocess, 1318.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1320.8ms
# Speed: 2.7ms preprocess, 1320.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1320.0ms
# Speed: 2.9ms preprocess, 1320.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1310.5ms
# Speed: 2.4ms preprocess, 1310.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1303.3ms
# Speed: 2.9ms preprocess, 1303.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1280.3ms
# Speed: 2.3ms preprocess, 1280.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1512.6ms
# Speed: 3.3ms preprocess, 1512.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1451.7ms
# Speed: 2.8ms preprocess, 1451.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1277.1ms
# Speed: 2.6ms preprocess, 1277.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1348.1ms
# Speed: 3.3ms preprocess, 1348.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1288.6ms
# Speed: 2.8ms preprocess, 1288.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1336.8ms
# Speed: 2.1ms preprocess, 1336.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1307.1ms
# Speed: 2.8ms preprocess, 1307.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1330.2ms
# Speed: 2.5ms preprocess, 1330.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1439.9ms
# Speed: 3.0ms preprocess, 1439.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1438.3ms
# Speed: 2.3ms preprocess, 1438.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1329.3ms
# Speed: 2.3ms preprocess, 1329.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1303.2ms
# Speed: 2.7ms preprocess, 1303.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1300.2ms
# Speed: 3.0ms preprocess, 1300.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1293.7ms
# Speed: 2.2ms preprocess, 1293.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1262.5ms
# Speed: 2.4ms preprocess, 1262.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1302.4ms
# Speed: 3.0ms preprocess, 1302.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1309.3ms
# Speed: 3.0ms preprocess, 1309.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1600.6ms
# Speed: 2.9ms preprocess, 1600.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1323.3ms
# Speed: 2.8ms preprocess, 1323.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1290.8ms
# Speed: 3.5ms preprocess, 1290.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1260.3ms
# Speed: 2.4ms preprocess, 1260.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1270.9ms
# Speed: 2.7ms preprocess, 1270.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1292.2ms
# Speed: 2.3ms preprocess, 1292.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1306.7ms
# Speed: 3.7ms preprocess, 1306.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1264.4ms
# Speed: 2.6ms preprocess, 1264.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1414.4ms
# Speed: 4.5ms preprocess, 1414.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1434.5ms
# Speed: 2.3ms preprocess, 1434.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1331.1ms
# Speed: 2.7ms preprocess, 1331.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1320.2ms
# Speed: 2.9ms preprocess, 1320.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1323.9ms
# Speed: 3.3ms preprocess, 1323.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1266.2ms
# Speed: 2.4ms preprocess, 1266.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1258.8ms
# Speed: 2.7ms preprocess, 1258.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1276.7ms
# Speed: 3.4ms preprocess, 1276.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1246.4ms
# Speed: 4.8ms preprocess, 1246.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1581.8ms
# Speed: 3.1ms preprocess, 1581.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1323.6ms
# Speed: 3.2ms preprocess, 1323.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1262.9ms
# Speed: 2.9ms preprocess, 1262.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1282.3ms
# Speed: 2.8ms preprocess, 1282.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1284.9ms
# Speed: 2.5ms preprocess, 1284.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1319.2ms
# Speed: 2.4ms preprocess, 1319.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1322.0ms
# Speed: 3.2ms preprocess, 1322.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1329.2ms
# Speed: 2.9ms preprocess, 1329.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1560.4ms
# Speed: 2.7ms preprocess, 1560.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1364.2ms
# Speed: 7.2ms preprocess, 1364.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1264.1ms
# Speed: 2.5ms preprocess, 1264.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1335.4ms
# Speed: 3.9ms preprocess, 1335.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1259.1ms
# ...
# Speed: 2.7ms preprocess, 1294.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1313.6ms
# Speed: 3.2ms preprocess, 1313.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1304.7ms
# Speed: 2.7ms preprocess, 1304.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1285.1ms
# Speed: 2.3ms preprocess, 1285.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1300.4ms
# Speed: 2.6ms preprocess, 1300.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1304.1ms
# Speed: 2.7ms preprocess, 1304.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1301.9ms
# Speed: 2.3ms preprocess, 1301.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1582.7ms
# Speed: 2.3ms preprocess, 1582.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1292.8ms
# Speed: 2.8ms preprocess, 1292.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1274.2ms
# Speed: 2.5ms preprocess, 1274.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1310.3ms
# Speed: 2.5ms preprocess, 1310.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1282.7ms
# Speed: 3.5ms preprocess, 1282.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1286.3ms
# Speed: 2.5ms preprocess, 1286.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1274.6ms
# Speed: 2.9ms preprocess, 1274.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1253.8ms
# Speed: 2.8ms preprocess, 1253.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1506.8ms
# Speed: 3.3ms preprocess, 1506.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1290.6ms
# Speed: 2.5ms preprocess, 1290.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1276.0ms
# Speed: 2.4ms preprocess, 1276.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1287.0ms
# Speed: 3.2ms preprocess, 1287.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1270.4ms
# Speed: 2.6ms preprocess, 1270.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1251.9ms
# Speed: 2.5ms preprocess, 1251.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1261.0ms
# Speed: 2.7ms preprocess, 1261.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1259.7ms
# Speed: 2.3ms preprocess, 1259.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1311.7ms
# Speed: 2.3ms preprocess, 1311.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1564.6ms
# Speed: 2.3ms preprocess, 1564.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1299.9ms
# Speed: 3.3ms preprocess, 1299.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1309.9ms
# Speed: 3.1ms preprocess, 1309.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1308.2ms
# Speed: 3.0ms preprocess, 1308.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1298.9ms
# Speed: 2.5ms preprocess, 1298.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1304.9ms
# Speed: 2.3ms preprocess, 1304.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1244.7ms
# Speed: 2.3ms preprocess, 1244.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1272.9ms
# Speed: 2.2ms preprocess, 1272.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1595.2ms
# Speed: 2.9ms preprocess, 1595.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1317.3ms
# Speed: 5.5ms preprocess, 1317.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1285.5ms
# Speed: 2.3ms preprocess, 1285.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1311.2ms
# Speed: 2.5ms preprocess, 1311.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1371.4ms
# Speed: 2.8ms preprocess, 1371.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1343.5ms
# Speed: 2.8ms preprocess, 1343.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1298.0ms
# Speed: 2.9ms preprocess, 1298.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1265.1ms
# Speed: 2.4ms preprocess, 1265.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1450.2ms
# Speed: 2.3ms preprocess, 1450.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1496.0ms
# Speed: 2.9ms preprocess, 1496.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1271.2ms
# Speed: 2.6ms preprocess, 1271.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1340.1ms
# Speed: 2.7ms preprocess, 1340.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1333.6ms
# Speed: 2.9ms preprocess, 1333.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1265.8ms
# Speed: 2.5ms preprocess, 1265.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1291.6ms
# Speed: 2.1ms preprocess, 1291.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1303.4ms
# Speed: 3.0ms preprocess, 1303.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1340.0ms
# Speed: 2.4ms preprocess, 1340.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1648.8ms
# Speed: 2.7ms preprocess, 1648.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1312.3ms
# Speed: 2.7ms preprocess, 1312.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1322.3ms
# Speed: 3.1ms preprocess, 1322.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1328.8ms
# Speed: 2.7ms preprocess, 1328.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1293.5ms
# Speed: 2.8ms preprocess, 1293.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1356.2ms
# Speed: 2.7ms preprocess, 1356.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1297.7ms
# Speed: 3.5ms preprocess, 1297.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1302.5ms
# Speed: 3.0ms preprocess, 1302.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1559.5ms
# Speed: 3.4ms preprocess, 1559.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1333.5ms
# Speed: 2.9ms preprocess, 1333.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1269.9ms
# Speed: 2.5ms preprocess, 1269.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1253.5ms
# Speed: 2.2ms preprocess, 1253.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1298.2ms
# Speed: 2.6ms preprocess, 1298.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1312.8ms
# Speed: 3.2ms preprocess, 1312.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1257.5ms
# Speed: 2.4ms preprocess, 1257.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1243.6ms
# Speed: 2.3ms preprocess, 1243.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1407.6ms
# Speed: 2.6ms preprocess, 1407.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1449.2ms
# Speed: 3.1ms preprocess, 1449.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1276.9ms
# Speed: 2.5ms preprocess, 1276.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1251.1ms
# Speed: 2.3ms preprocess, 1251.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1305.3ms
# Speed: 2.2ms preprocess, 1305.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1295.5ms
# Speed: 2.4ms preprocess, 1295.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1299.6ms
# Speed: 3.2ms preprocess, 1299.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1283.3ms
# Speed: 2.8ms preprocess, 1283.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1317.9ms
# Speed: 2.7ms preprocess, 1317.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1607.6ms
# Speed: 3.6ms preprocess, 1607.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1319.0ms
# Speed: 4.0ms preprocess, 1319.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1290.1ms
# Speed: 2.3ms preprocess, 1290.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1304.6ms
# Speed: 2.6ms preprocess, 1304.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1291.8ms
# Speed: 2.2ms preprocess, 1291.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1272.0ms
# Speed: 2.4ms preprocess, 1272.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1318.4ms
# Speed: 2.8ms preprocess, 1318.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1329.0ms
# Speed: 2.7ms preprocess, 1329.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1441.1ms
# Speed: 2.2ms preprocess, 1441.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1419.3ms
# Speed: 2.8ms preprocess, 1419.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1281.2ms
# Speed: 2.3ms preprocess, 1281.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1287.8ms
# Speed: 2.3ms preprocess, 1287.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1260.4ms
# Speed: 3.0ms preprocess, 1260.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1261.8ms
# Speed: 2.4ms preprocess, 1261.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1308.4ms
# Speed: 2.3ms preprocess, 1308.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1287.5ms
# Speed: 2.6ms preprocess, 1287.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1258.3ms
# Speed: 2.1ms preprocess, 1258.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1616.7ms
# Speed: 2.4ms preprocess, 1616.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1283.4ms
# Speed: 2.7ms preprocess, 1283.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1272.6ms
# Speed: 2.5ms preprocess, 1272.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1274.3ms
# Speed: 2.3ms preprocess, 1274.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1267.6ms
# Speed: 2.3ms preprocess, 1267.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1263.0ms
# Speed: 2.4ms preprocess, 1263.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1328.9ms
# Speed: 2.2ms preprocess, 1328.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1304.3ms
# Speed: 3.0ms preprocess, 1304.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1509.9ms
# Speed: 2.5ms preprocess, 1509.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1455.7ms
# Speed: 2.5ms preprocess, 1455.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1299.3ms
# Speed: 3.2ms preprocess, 1299.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1297.3ms
# Speed: 3.0ms preprocess, 1297.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1326.1ms
# Speed: 2.2ms preprocess, 1326.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1305.5ms
# Speed: 2.8ms preprocess, 1305.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1310.1ms
# Speed: 2.5ms preprocess, 1310.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1329.7ms
# Speed: 6.4ms preprocess, 1329.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1364.6ms
# Speed: 2.8ms preprocess, 1364.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1574.1ms
# Speed: 2.5ms preprocess, 1574.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1331.2ms
# Speed: 2.7ms preprocess, 1331.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1330.9ms
# Speed: 2.7ms preprocess, 1330.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1305.6ms
# Speed: 3.3ms preprocess, 1305.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1306.9ms
# Speed: 2.4ms preprocess, 1306.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1321.7ms
# Speed: 3.0ms preprocess, 1321.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1280.8ms
# Speed: 5.6ms preprocess, 1280.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1313.2ms
# Speed: 2.5ms preprocess, 1313.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 1607.1ms
# Speed: 2.7ms preprocess, 1607.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# Анализ субтитров (если доступны)

# %%
def extract_subtitles(audio_path, language='en'):
    r = sr.Recognizer()
    audio_file = sr.AudioFile(audio_path)

    subtitles = []

    with audio_file as source:
        duration = audio_file.DURATION
        chunk_size = 10  # секунды

        for i in range(0, int(duration), chunk_size):
            try:
                audio = r.record(source, duration=chunk_size, offset=i)
                text = r.recognize_google(audio, language=language)
                subtitles.append({
                    'start': i,
                    'end': i + chunk_size,
                    'text': text
                })
            except Exception as e:
                print(f"Ошибка при обработке отрезка {i}-{i+chunk_size}: {e}")
                continue

    return subtitles

# Пример использования (раскомментируйте при необходимости)
subtitles = extract_subtitles(audio_path)
for sub in subtitles:
  print(f"{sub['start']:.1f}-{sub['end']:.1f}: {sub['text']}")
# Out:
# Ошибка при обработке отрезка 10-20:
# Ошибка при обработке отрезка 20-30:
# Ошибка при обработке отрезка 40-50:
# Ошибка при обработке отрезка 60-70:
# Ошибка при обработке отрезка 70-80:
# Ошибка при обработке отрезка 80-90:
# Ошибка при обработке отрезка 90-100:
# Ошибка при обработке отрезка 100-110:
# Ошибка при обработке отрезка 120-130:
# Ошибка при обработке отрезка 130-140:
# Ошибка при обработке отрезка 140-150:
# Ошибка при обработке отрезка 150-160:
# Ошибка при обработке отрезка 160-170:
# Ошибка при обработке отрезка 170-180:
# Ошибка при обработке отрезка 180-190:
# Ошибка при обработке отрезка 190-200:
# Ошибка при обработке отрезка 200-210:
# Ошибка при обработке отрезка 210-220:
# Ошибка при обработке отрезка 220-230:
# Ошибка при обработке отрезка 230-240:
# Ошибка при обработке отрезка 240-250:
# Ошибка при обработке отрезка 250-260:
# Ошибка при обработке отрезка 260-270:
# Ошибка при обработке отрезка 270-280:
# Ошибка при обработке отрезка 280-290:
# Ошибка при обработке отрезка 290-300:
# Ошибка при обработке отрезка 300-310:
# Ошибка при обработке отрезка 310-320:
# Ошибка при обработке отрезка 320-330:
# Ошибка при обработке отрезка 330-340:
# Ошибка при обработке отрезка 340-350:
# Ошибка при обработке отрезка 350-360:
# Ошибка при обработке отрезка 360-370:
# Ошибка при обработке отрезка 370-380:
# Ошибка при обработке отрезка 380-390:
# Ошибка при обработке отрезка 390-400:
# Ошибка при обработке отрезка 400-410:
# Ошибка при обработке отрезка 410-420:
# Ошибка при обработке отрезка 420-430:
# Ошибка при обработке отрезка 430-440:
# Ошибка при обработке отрезка 440-450:
# Ошибка при обработке отрезка 450-460:
# Ошибка при обработке отрезка 460-470:
# Ошибка при обработке отрезка 470-480:
# Ошибка при обработке отрезка 480-490:
# Ошибка при обработке отрезка 490-500:
# Ошибка при обработке отрезка 500-510:
# Ошибка при обработке отрезка 510-520:
# Ошибка при обработке отрезка 520-530:
# Ошибка при обработке отрезка 530-540:
# Ошибка при обработке отрезка 540-550:
# Ошибка при обработке отрезка 550-560:
# Ошибка при обработке отрезка 560-570:
# Ошибка при обработке отрезка 570-580:
# Ошибка при обработке отрезка 580-590:
# Ошибка при обработке отрезка 590-600:
# Ошибка при обработке отрезка 600-610:
# Ошибка при обработке отрезка 610-620:
# Ошибка при обработке отрезка 620-630:
# Ошибка при обработке отрезка 630-640:
# Ошибка при обработке отрезка 640-650:
# Ошибка при обработке отрезка 650-660:
# Ошибка при обработке отрезка 660-670:
# Ошибка при обработке отрезка 670-680:
# Ошибка при обработке отрезка 680-690:
# Ошибка при обработке отрезка 690-700:
# Ошибка при обработке отрезка 700-710:
# Ошибка при обработке отрезка 710-720:
# Ошибка при обработке отрезка 720-730:
# Ошибка при обработке отрезка 730-740:
# Ошибка при обработке отрезка 740-750:
# Ошибка при обработке отрезка 750-760:
# Ошибка при обработке отрезка 760-770:
# Ошибка при обработке отрезка 770-780:
# Ошибка при обработке отрезка 780-790:
# Ошибка при обработке отрезка 790-800:
# Ошибка при обработке отрезка 800-810:
# Ошибка при обработке отрезка 810-820:
# Ошибка при обработке отрезка 820-830:
# Ошибка при обработке отрезка 830-840:
# Ошибка при обработке отрезка 840-850:
# Ошибка при обработке отрезка 850-860:
# Ошибка при обработке отрезка 860-870:
# Ошибка при обработке отрезка 870-880:
# Ошибка при обработке отрезка 880-890:
# Ошибка при обработке отрезка 890-900:
# Ошибка при обработке отрезка 900-910:
# Ошибка при обработке отрезка 910-920:
# Ошибка при обработке отрезка 920-930:
# Ошибка при обработке отрезка 930-940:
# Ошибка при обработке отрезка 940-950:
# Ошибка при обработке отрезка 950-960:
# Ошибка при обработке отрезка 960-970:
# Ошибка при обработке отрезка 970-980:
# Ошибка при обработке отрезка 980-990:
# Ошибка при обработке отрезка 990-1000:
# Ошибка при обработке отрезка 1000-1010:
# Ошибка при обработке отрезка 1010-1020:
# Ошибка при обработке отрезка 1020-1030:
# Ошибка при обработке отрезка 1030-1040:
# Ошибка при обработке отрезка 1040-1050:
# Ошибка при обработке отрезка 1050-1060:
# Ошибка при обработке отрезка 1060-1070:
# Ошибка при обработке отрезка 1070-1080:
# Ошибка при обработке отрезка 1080-1090:
# Ошибка при обработке отрезка 1090-1100:
# Ошибка при обработке отрезка 1100-1110:
# Ошибка при обработке отрезка 1110-1120:
# Ошибка при обработке отрезка 1120-1130:
# Ошибка при обработке отрезка 1130-1140:
# Ошибка при обработке отрезка 1140-1150:
# Ошибка при обработке отрезка 1150-1160:
# 0.0-10.0: Simply Red
# 30.0-40.0: useless minions
# 50.0-60.0: muscular
# 110.0-120.0: watch Cartoon Network

# %% [markdown]
# Объединение всех данных для финальной сегментации

# %%
def final_scene_segmentation(merged_scenes, tracks_info, subtitles=None, min_scene_duration=5.0):
    final_scenes = []

    for scene_start, scene_end in merged_scenes:
        # Проверяем продолжительность сцены
        if scene_end - scene_start < min_scene_duration:
            continue

        # Анализируем объекты в сцене
        scene_tracks = {}
        for track_id, track_data in tracks_info.items():
            # Фильтруем объекты, которые находятся в текущей сцене
            objects_in_scene = [obj for obj in track_data if scene_start <= obj['time'] <= scene_end]
            if objects_in_scene:
                scene_tracks[track_id] = objects_in_scene

        # Анализируем субтитры (если есть)
        scene_text = ""
        if subtitles:
            for sub in subtitles:
                if scene_start <= sub['start'] <= scene_end or scene_start <= sub['end'] <= scene_end:
                    scene_text += sub['text'] + " "

        # Добавляем сцену в финальный список
        final_scenes.append({
            'start': scene_start,
            'end': scene_end,
            'duration': scene_end - scene_start,
            'objects': scene_tracks,
            'text': scene_text.strip() if scene_text else None
        })

    return final_scenes

final_scenes = final_scene_segmentation(merged_scenes, tracks_info)  # , subtitles)

# Выводим информацию о финальных сценах
print("\nФинальная сегментация сцен:")
for i, scene in enumerate(final_scenes):
    print(f"\nСцена {i+1}:")
    print(f"Время: {scene['start']:.2f} - {scene['end']:.2f} сек (длительность: {scene['duration']:.2f} сек)")
    print(f"Количество уникальных объектов: {len(scene['objects'])}")
    if scene['text']:
        print(f"Текст: {scene['text'][:100]}...")
# Out:
# Финальная сегментация сцен:
#
# Сцена 1:
# Время: 0.00 - 12.62 сек (длительность: 12.62 сек)
# Количество уникальных объектов: 4
#
# Сцена 2:
# Время: 0.00 - 59.21 сек (длительность: 59.21 сек)
# Количество уникальных объектов: 99
#
# Сцена 3:
# Время: 64.62 - 76.54 сек (длительность: 11.92 сек)
# Количество уникальных объектов: 22
#
# Сцена 4:
# Время: 87.17 - 103.38 сек (длительность: 16.21 сек)
# Количество уникальных объектов: 17
#
# Сцена 5:
# Время: 95.11 - 146.33 сек (длительность: 51.22 сек)
# Количество уникальных объектов: 104
#
# Сцена 6:
# Время: 146.33 - 204.71 сек (длительность: 58.38 сек)
# Количество уникальных объектов: 115
#
# Сцена 7:
# Время: 204.71 - 234.12 сек (длительность: 29.42 сек)
# Количество уникальных объектов: 80
#
# Сцена 8:
# Время: 244.29 - 303.29 сек (длительность: 59.00 сек)
# Количество уникальных объектов: 107
#
# Сцена 9:
# Время: 303.29 - 310.21 сек (длительность: 6.92 сек)
# Количество уникальных объектов: 10
#
# Сцена 10:
# Время: 313.00 - 318.62 сек (длительность: 5.62 сек)
# Количество уникальных объектов: 3
#
# Сцена 11:
# Время: 321.58 - 333.83 сек (длительность: 12.25 сек)
# Количество уникальных объектов: 19
#
# Сцена 12:
# Время: 336.29 - 390.17 сек (длительность: 53.88 сек)
# Количество уникальных объектов: 104
#
# Сцена 13:
# Время: 390.17 - 446.25 сек (длительность: 56.08 сек)
# Количество уникальных объектов: 41
#
# Сцена 14:
# Время: 446.25 - 483.88 сек (длительность: 37.62 сек)
# Количество уникальных объектов: 7
#
# Сцена 15:
# Время: 486.17 - 511.12 сек (длительность: 24.96 сек)
# Количество уникальных объектов: 7
#
# Сцена 16:
# Время: 494.72 - 554.42 сек (длительность: 59.69 сек)
# Количество уникальных объектов: 62
#
# Сцена 17:
# Время: 554.42 - 607.67 сек (длительность: 53.25 сек)
# Количество уникальных объектов: 74
#
# Сцена 18:
# Время: 610.33 - 668.75 сек (длительность: 58.42 сек)
# Количество уникальных объектов: 95
#
# Сцена 19:
# Время: 668.75 - 689.42 сек (длительность: 20.67 сек)
# Количество уникальных объектов: 37
#
# Сцена 20:
# Время: 695.46 - 731.67 сек (длительность: 36.21 сек)
# Количество уникальных объектов: 83
#
# Сцена 21:
# Время: 734.04 - 751.71 сек (длительность: 17.67 сек)
# Количество уникальных объектов: 80
#
# Сцена 22:
# Время: 754.38 - 786.38 сек (длительность: 32.00 сек)
# Количество уникальных объектов: 36
#
# Сцена 23:
# Время: 788.88 - 793.96 сек (длительность: 5.08 сек)
# Количество уникальных объектов: 1
#
# Сцена 24:
# Время: 800.33 - 849.58 сек (длительность: 49.25 сек)
# Количество уникальных объектов: 88
#
# Сцена 25:
# Время: 849.58 - 899.62 сек (длительность: 50.04 сек)
# Количество уникальных объектов: 122
#
# Сцена 26:
# Время: 899.62 - 938.08 сек (длительность: 38.46 сек)
# Количество уникальных объектов: 66
#
# Сцена 27:
# Время: 938.08 - 974.08 сек (длительность: 36.00 сек)
# Количество уникальных объектов: 33
#
# Сцена 28:
# Время: 976.62 - 985.58 сек (длительность: 8.96 сек)
# Количество уникальных объектов: 12
#
# Сцена 29:
# Время: 995.33 - 1023.00 сек (длительность: 27.67 сек)
# Количество уникальных объектов: 98
#
# Сцена 30:
# Время: 1025.88 - 1081.88 сек (длительность: 56.00 сек)
# Количество уникальных объектов: 106
#
# Сцена 31:
# Время: 1088.67 - 1112.38 сек (длительность: 23.71 сек)
# Количество уникальных объектов: 43
#
# Сцена 32:
# Время: 1114.67 - 1121.12 сек (длительность: 6.46 сек)
# Количество уникальных объектов: 17
#
# Сцена 33:
# Время: 1124.08 - 1160.38 сек (длительность: 36.29 сек)
# Количество уникальных объектов: 28

# %% [markdown]
# Визуализация результатов

# %%
def visualize_scenes(final_scenes, video_path):
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)

    plt.figure(figsize=(15, 5))

    # Создаем временную шкалу
    duration = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000
    time_axis = np.linspace(0, duration, 100)

    # Визуализируем сцены
    for i, scene in enumerate(final_scenes):
        plt.axvspan(scene['start'], scene['end'], alpha=0.3, color=f'C{i}', label=f'Сцена {i+1}')

    plt.title('Сегментация видео на сцены')
    plt.xlabel('Время (секунды)')
    plt.ylabel('Сцены')
    plt.legend()
    plt.show()

    cap.release()

visualize_scenes(final_scenes, video_path)

# %% [markdown]
# Сохранение сцен как отдельных видеофайлов

# %%
def save_scenes_as_videos(video_path, final_scenes, output_dir='./scenes'):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    video_name = os.path.splitext(os.path.basename(video_path))[0]

    for i, scene in enumerate(final_scenes):
        output_path = os.path.join(output_dir, f"{video_name}_scene_{i+1}.mp4")

        # Используем moviepy для вырезания сцены
        clip = VideoFileClip(video_path).subclip(scene['start'], scene['end'])
        clip.write_videofile(output_path, codec='libx264', audio_codec='aac')

        print(f"Сохранена сцена {i+1} в {output_path}")

save_scenes_as_videos(video_path, final_scenes)
# Out:
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_1.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_1TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_1.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_1.mp4
# Сохранена сцена 1 в ./scenes/30 секунд (2023)_1080p_scene_1.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_2.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_2TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_2.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_2.mp4
# Сохранена сцена 2 в ./scenes/30 секунд (2023)_1080p_scene_2.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_3.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_3TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_3.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_3.mp4
# Сохранена сцена 3 в ./scenes/30 секунд (2023)_1080p_scene_3.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_4.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_4TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_4.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_4.mp4
# Сохранена сцена 4 в ./scenes/30 секунд (2023)_1080p_scene_4.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_5.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_5TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_5.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_5.mp4
# Сохранена сцена 5 в ./scenes/30 секунд (2023)_1080p_scene_5.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_6.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_6TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_6.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_6.mp4
# Сохранена сцена 6 в ./scenes/30 секунд (2023)_1080p_scene_6.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_7.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_7TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_7.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_7.mp4
# Сохранена сцена 7 в ./scenes/30 секунд (2023)_1080p_scene_7.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_8.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_8TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_8.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_8.mp4
# Сохранена сцена 8 в ./scenes/30 секунд (2023)_1080p_scene_8.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_9.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_9TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_9.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_9.mp4
# Сохранена сцена 9 в ./scenes/30 секунд (2023)_1080p_scene_9.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_10.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_10TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_10.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_10.mp4
# Сохранена сцена 10 в ./scenes/30 секунд (2023)_1080p_scene_10.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_11.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_11TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_11.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_11.mp4
# Сохранена сцена 11 в ./scenes/30 секунд (2023)_1080p_scene_11.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_12.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_12TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_12.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_12.mp4
# Сохранена сцена 12 в ./scenes/30 секунд (2023)_1080p_scene_12.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_13.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_13TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_13.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_13.mp4
# Сохранена сцена 13 в ./scenes/30 секунд (2023)_1080p_scene_13.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_14.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_14TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_14.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_14.mp4
# Сохранена сцена 14 в ./scenes/30 секунд (2023)_1080p_scene_14.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_15.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_15TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_15.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_15.mp4
# Сохранена сцена 15 в ./scenes/30 секунд (2023)_1080p_scene_15.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_16.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_16TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_16.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_16.mp4
# Сохранена сцена 16 в ./scenes/30 секунд (2023)_1080p_scene_16.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_17.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_17TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_17.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_17.mp4
# Сохранена сцена 17 в ./scenes/30 секунд (2023)_1080p_scene_17.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_18.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_18TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_18.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_18.mp4
# Сохранена сцена 18 в ./scenes/30 секунд (2023)_1080p_scene_18.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_19.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_19TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_19.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_19.mp4
# Сохранена сцена 19 в ./scenes/30 секунд (2023)_1080p_scene_19.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_20.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_20TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_20.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_20.mp4
# Сохранена сцена 20 в ./scenes/30 секунд (2023)_1080p_scene_20.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_21.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_21TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_21.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_21.mp4
# Сохранена сцена 21 в ./scenes/30 секунд (2023)_1080p_scene_21.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_22.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_22TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_22.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_22.mp4
# Сохранена сцена 22 в ./scenes/30 секунд (2023)_1080p_scene_22.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_23.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_23TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_23.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_23.mp4
# Сохранена сцена 23 в ./scenes/30 секунд (2023)_1080p_scene_23.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_24.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_24TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_24.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_24.mp4
# Сохранена сцена 24 в ./scenes/30 секунд (2023)_1080p_scene_24.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_25.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_25TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_25.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_25.mp4
# Сохранена сцена 25 в ./scenes/30 секунд (2023)_1080p_scene_25.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_26.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_26TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_26.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_26.mp4
# Сохранена сцена 26 в ./scenes/30 секунд (2023)_1080p_scene_26.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_27.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_27TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_27.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_27.mp4
# Сохранена сцена 27 в ./scenes/30 секунд (2023)_1080p_scene_27.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_28.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_28TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_28.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_28.mp4
# Сохранена сцена 28 в ./scenes/30 секунд (2023)_1080p_scene_28.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_29.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_29TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_29.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_29.mp4
# Сохранена сцена 29 в ./scenes/30 секунд (2023)_1080p_scene_29.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_30.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_30TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_30.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_30.mp4
# Сохранена сцена 30 в ./scenes/30 секунд (2023)_1080p_scene_30.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_31.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_31TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_31.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_31.mp4
# Сохранена сцена 31 в ./scenes/30 секунд (2023)_1080p_scene_31.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_32.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_32TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_32.mp4
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_32.mp4
# Сохранена сцена 32 в ./scenes/30 секунд (2023)_1080p_scene_32.mp4
# Moviepy - Building video ./scenes/30 секунд (2023)_1080p_scene_33.mp4.
# MoviePy - Writing audio in 30 секунд (2023)_1080p_scene_33TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video ./scenes/30 секунд (2023)_1080p_scene_33.mp4
# t:  99%|█████████▉| 867/872 [00:56<00:00, 35.96it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file 30 секунд (2023)_1080p.mp4, 6220800 bytes wanted but 0 bytes read,at frame 27849/27850, at time 1160.38/1160.38 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready ./scenes/30 секунд (2023)_1080p_scene_33.mp4
# Сохранена сцена 33 в ./scenes/30 секунд (2023)_1080p_scene_33.mp4

# %% [markdown]
# Генерация отчета

# %%
def generate_report(final_scenes, output_path='report.csv'):
    report_data = []

    for i, scene in enumerate(final_scenes):
        # Основная информация о сцене
        scene_info = {
            'scene_number': i+1,
            'start_time': scene['start'],
            'end_time': scene['end'],
            'duration': scene['duration'],
            'num_objects': len(scene['objects']),
            'main_objects': ', '.join([f"ID {track_id}" for track_id in scene['objects']][:3]) + ('...' if len(scene['objects']) > 3 else '')
        }

        # Добавляем текст (если есть)
        if scene['text']:
            scene_info['text_sample'] = scene['text'][:100] + ('...' if len(scene['text']) > 100 else '')
        else:
            scene_info['text_sample'] = ''

        report_data.append(scene_info)

    # Создаем DataFrame и сохраняем в CSV
    df = pd.DataFrame(report_data)
    df.to_csv(output_path, index=False)
    print(f"Отчет сохранен в {output_path}")

    return df

report_df = generate_report(final_scenes)
display(report_df)
# Out:
# Отчет сохранен в report.csv
#     scene_number   start_time     end_time   duration  num_objects  \
# 0              1     0.000000    12.625000  12.625000            4
# 1              2     0.000000    59.208333  59.208333           99
# 2              3    64.625000    76.541667  11.916667           22
# 3              4    87.166667   103.375000  16.208333           17
# 4              5    95.108934   146.333333  51.224399          104
# 5              6   146.333333   204.708333  58.375000          115
# 6              7   204.708333   234.125000  29.416667           80
# 7              8   244.291667   303.291667  59.000000          107
# 8              9   303.291667   310.208333   6.916667           10
# 9             10   313.000000   318.625000   5.625000            3
# 10            11   321.583333   333.833333  12.250000           19
# 11            12   336.291667   390.166667  53.875000          104
# 12            13   390.166667   446.250000  56.083333           41
# 13            14   446.250000   483.875000  37.625000            7
# 14            15   486.166667   511.125000  24.958333            7
# 15            16   494.724354   554.416667  59.692313           62
# 16            17   554.416667   607.666667  53.250000           74
# 17            18   610.333333   668.750000  58.416667           95
# 18            19   668.750000   689.416667  20.666667           37
# 19            20   695.458333   731.666667  36.208333           83
# 20            21   734.041667   751.708333  17.666667           80
# 21            22   754.375000   786.375000  32.000000           36
# 22            23   788.875000   793.958333   5.083333            1
# 23            24   800.333333   849.583333  49.250000           88
# 24            25   849.583333   899.625000  50.041667          122
# 25            26   899.625000   938.083333  38.458333           66
# 26            27   938.083333   974.083333  36.000000           33
# 27            28   976.625000   985.583333   8.958333           12
# 28            29   995.333333  1023.000000  27.666667           98
# 29            30  1025.875000  1081.875000  56.000000          106
# 30            31  1088.666667  1112.375000  23.708333           43
# 31            32  1114.666667  1121.125000   6.458333           17
# 32            33  1124.083333  1160.375000  36.291667           28
#
#                     main_objects text_sample
# 0            ID 1, ID 8, ID 9...
# 1            ID 1, ID 8, ID 9...
# 2      ID 489, ID 500, ID 507...
# 3      ID 624, ID 648, ID 650...
# 4      ID 624, ID 653, ID 671...
# 5   ID 1024, ID 1067, ID 1070...
# 6   ID 1344, ID 1448, ID 1525...
# 7   ID 1869, ID 2023, ID 2031...
# 8   ID 2418, ID 2471, ID 2483...
# 9      ID 2418, ID 2538, ID 2544
# 10  ID 2418, ID 2544, ID 2562...
# 11  ID 2418, ID 2544, ID 2670...
# 12  ID 2544, ID 2999, ID 3067...
# 13  ID 2544, ID 3237, ID 3238...
# 14  ID 2544, ID 3257, ID 3270...
# 15  ID 2544, ID 3270, ID 3288...
# 16  ID 3534, ID 3625, ID 3684...
# 17  ID 3845, ID 3882, ID 4063...
# 18  ID 4487, ID 4503, ID 4504...
# 19  ID 4651, ID 4679, ID 4683...
# 20  ID 5270, ID 5362, ID 5367...
# 21  ID 6000, ID 6001, ID 6005...
# 22                       ID 6267
# 23  ID 6399, ID 6400, ID 6401...
# 24  ID 6631, ID 6635, ID 6656...
# 25  ID 6766, ID 6986, ID 7032...
# 26  ID 7204, ID 7253, ID 7259...
# 27  ID 7439, ID 7450, ID 7453...
# 28  ID 7644, ID 7645, ID 7652...
# 29  ID 8043, ID 8049, ID 8050...
# 30  ID 8545, ID 8546, ID 8547...
# 31  ID 8732, ID 8733, ID 8734...
# 32  ID 8854, ID 8855, ID 8856...
